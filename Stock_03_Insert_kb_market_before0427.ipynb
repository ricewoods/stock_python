# %%
import pandas as pd
import sqlalchemy as sa
import pymysql

# %%
# Inputファイル日付
filedate = '20220425'
trading_date = pd.to_datetime(filedate)
trading_date
# Out:
# Timestamp('2022-04-25 00:00:00')

# %%
# Mysqlへ接続
url = 'mysql+pymysql://cyamaryan:python@localhost:13306/stock?charset=utf8mb4'
# engineの作成
engine = sa.create_engine(url, echo=False)

# %%
# TABLE(kb_market)の作成/銘柄リスト
df_market = pd.read_csv('data/market_' + filedate + '.csv', index_col=None, header=None, thousands=',')

# %%
# パターン２：2022/4/4以降データ
pd.set_option('display.max_rows', None) 
# defult:60,制限なし:None
pd.set_option('display.max_columns', None) 
# defult:20,制限なし:None
# df_market.iloc[2:,[1:27,79:97,133:173,213:223,243:257,271:288]]<-これはエラー
df_insert = pd.concat([df_market.iloc[2:,1:27], df_market.iloc[2:,79:97],
           df_market.iloc[2:,133:173], df_market.iloc[2:,213:223],
           df_market.iloc[2:,243:257], df_market.iloc[2:,271:288],
          ], axis=1)

# %%
df_insert.columns = ['nikkei225', 'topix', 'jpxni400', 'mothers', 'nikkei_vi', 'reit', 'dow', 'nasdaq', 'sp500', 'gbr_ft', 'fra_cac', 'ger_dax', 'rus_rts', 'bra_bvsp', 'ind_sensex', 'hkg_han', 'hkg_han_h', 'hkg_red', 'shanghai', 'shanghai_a', 'Shang_hongkong', 'csi300', 'singapore_st', 'thailand_set', 'kualalumpur', 'Jakarta', 'nikkei225_futures', 'cme_futures', 'sgx_futures', 'mothers_futures', 'nikkei400_futures', 'jpn_bonds_futures', 'jpn_bonds_futures_lev', 'jpn_bonds_futures_In', 'jpn_bonds_futures_Inw', 'twn_futures', 'chn_futures', 'emini500', 'emini400', 'emini600', 'emini_nasdaq', 'emini_Dow', 'emini_nikkei225', 'sgx50', 'usd_jpy_buy', 'eur_jpy_buy', 'aud_jpy_buy', 'nzd_jpy_buy', 'cad_jpy_buy', 'chf_jpy_buy', 'hkd_jpy_buy', 'gbp_jpy_buy', 'try_jpy_buy', 'zar_jpy_buy', 'rub_jpy_buy', 'krw_jpy_buy', 'mxn_jpy_buy', 'brl_jpy_buy', 'inr_jpy_buy', 'cny_jpy_buy', 'sgd_jpy_buy', 'thb_jpy_buy', 'myr_jpy_buy', 'idr_jpy_buy', 'usd_jpy_sell', 'eur_jpy_sell', 'aud_jpy_sell', 'nzd_jpy_sell', 'cad_jpy_sell', 'chf_jpy_sell', 'hkd_jpy_sell', 'gbp_jpy_sell', 'try_jpy_sell', 'zar_jpy_sell', 'rub_jpy_sell', 'krw_jpy_sell', 'mxn_jpy_sell', 'brl_jpy_sell', 'inr_jpy_sell', 'cny_jpy_sell', 'sgd_jpy_sell', 'thb_jpy_sell', 'myr_jpy_sell', 'idr_jpy_sell', 'oll_futures', 'gas_futures', 'gold_buy', 'gold_futures', 'platinum_futures', 'silver_futures', 'copper_futures', 'corn_futures', 'wheat_futures', 'soybeans_futures', 'jpn_bonds_3y', 'jpn_bonds_5y', 'jpn_bonds_10y', 'usa_bonds_5y', 'usa_bonds_10y', 'ger_bonds_10y', 'eng_bonds_10y', 'Fra_bonds_10y', 'esp_bonds_10y', 'por_bonds_10y', 'eur_bonds_10y', 'ita_bonds_10y', 'grc_bonds_10y', 'hun_bonds_10y', 'jpn_call', 'official_discount_rate', 'usa_inter_rate', 'can_inter_rate', 'eur_inter_rate', 'gbr_inter_rate', 'she_inter_rate', 'zaf_inter_rate', 'hkg_inter_rate', 'aus_inter_rate', 'nzl_inter_rate', 'ind_inter_rate', 'chn_inter_rate', 'bra_inter_rate', 'rus_inter_rate', 'tur_inter_rate', 'mex_inter_rate']

# %%
df_insert['trading_date'] = trading_date

# %%
df_insert.replace({'--':0, '--%':0}, inplace=True)

# %%
df_insert.replace({'%':'', ',':''}, regex=True, inplace=True)

# %%
#df.to_sql(<table_name>,con=engine, if_exists='append', index=False)
df_insert.to_sql('kb_market',con=engine, if_exists='append', index=False)

# %%
df_insert
# Out:
#   nikkei225    topix  jpxni400 mothers nikkei_vi     reit       dow    nasdaq  \
# 2  26700.11  1878.51  16952.10  711.44     25.60  1988.65  33240.18  12490.74
#
#      sp500   gbr_ft  fra_cac   ger_dax rus_rts   bra_bvsp ind_sensex  \
# 2  4175.20  7386.19  6414.57  13756.40  999.84  108212.86   57356.61
#
#     hkg_han hkg_han_h  hkg_red  shanghai shanghai_a Shang_hongkong   csi300  \
# 2  19934.71   6747.42  3768.82  2886.426    3025.03        2948.79  3784.12
#
#   singapore_st thailand_set kualalumpur  Jakarta nikkei225_futures  \
# 2      3322.05      1668.97     1596.68  7232.15             26000
#
#   cme_futures sgx_futures mothers_futures nikkei400_futures jpn_bonds_futures  \
# 2       26100    25990.00           681.0             16555          11714.43
#
#   jpn_bonds_futures_lev jpn_bonds_futures_In jpn_bonds_futures_Inw  \
# 2              13641.50              8485.89               7158.36
#
#   twn_futures chn_futures emini500 emini400 emini600 emini_nasdaq emini_Dow  \
# 2           0           0     4170   2513.4   1227.9      12976.5     33244
#
#   emini_nikkei225     sgx50 usd_jpy_buy eur_jpy_buy aud_jpy_buy nzd_jpy_buy  \
# 2           26070  16867.50      127.27      135.45       90.86       83.63
#
#   cad_jpy_buy chf_jpy_buy hkd_jpy_buy gbp_jpy_buy try_jpy_buy zar_jpy_buy  \
# 2       99.31      160.06      132.21     16.2178      8.5931      8.0213
#
#   rub_jpy_buy krw_jpy_buy mxn_jpy_buy brl_jpy_buy inr_jpy_buy cny_jpy_buy  \
# 2      1.6287      0.1009      6.2385      25.450      1.6589     19.4023
#
#   sgd_jpy_buy thb_jpy_buy myr_jpy_buy idr_jpy_buy usd_jpy_sell eur_jpy_sell  \
# 2     92.2631      3.7085     29.2069      0.8829       127.28       135.55
#
#   aud_jpy_sell nzd_jpy_sell cad_jpy_sell chf_jpy_sell hkd_jpy_sell  \
# 2        90.92        83.72        99.36       160.21       132.32
#
#   gbp_jpy_sell try_jpy_sell zar_jpy_sell rub_jpy_sell krw_jpy_sell  \
# 2      16.2250       8.6020       8.0271       1.7407       0.1009
#
#   mxn_jpy_sell brl_jpy_sell inr_jpy_sell cny_jpy_sell sgd_jpy_sell  \
# 2       6.2449       25.465       1.6604      19.4182      92.3596
#
#   thb_jpy_sell myr_jpy_sell idr_jpy_sell oll_futures gas_futures   gold_buy  \
# 2       3.7143      29.2385       0.8833      101.71       7.015  1905.0352
#
#   gold_futures platinum_futures silver_futures copper_futures corn_futures  \
# 2       1901.4            911.9         23.542           4.44       803.25
#
#   wheat_futures soybeans_futures jpn_bonds_3y jpn_bonds_5y jpn_bonds_10y  \
# 2       1083.25          1705.25       -0.032        0.018         0.250
#
#   usa_bonds_5y usa_bonds_10y ger_bonds_10y eng_bonds_10y Fra_bonds_10y  \
# 2        2.658         2.728         0.808         1.815         1.306
#
#   esp_bonds_10y por_bonds_10y eur_bonds_10y ita_bonds_10y grc_bonds_10y  \
# 2         1.818         1.862         0.808         2.545         2.970
#
#   hun_bonds_10y jpn_call official_discount_rate usa_inter_rate can_inter_rate  \
# 2         6.890   -0.017                    0.3           0.50           1.00
#
#    eur_inter_rate gbr_inter_rate she_inter_rate zaf_inter_rate hkg_inter_rate  \
# 2               0           0.75        -0.7500           4.25              5
#
#   aus_inter_rate nzl_inter_rate ind_inter_rate chn_inter_rate bra_inter_rate  \
# 2           0.10           1.50           4.00           4.35          11.75
#
#    rus_inter_rate tur_inter_rate mex_inter_rate trading_date
# 2               0          12.50           6.52   2022-04-25
