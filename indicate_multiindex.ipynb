# %%
import pandas as pd

# %%
# 予想前日の株価データ
df_stock = pd.read_csv('data/stock_20220426.csv', index_col=None, header=None, parse_dates=[0])

# %%
df_stock
# Out:
#          0                 1                 2                  3      \
# 0   Attributes         Adj Close         Adj Close          Adj Close
# 1      Symbols            1301.T            1332.T             1333.T
# 2         Date               NaN               NaN                NaN
# 3   2022-03-28  3419.22412109375  577.939208984375  2515.811279296875
# 4   2022-03-29            3390.0             571.0             2504.0
# 5   2022-03-30            3355.0             558.0             2444.0
# 6   2022-03-31            3330.0             548.0             2397.0
# 7   2022-04-01            3435.0             549.0             2411.0
# 8   2022-04-04            3420.0             555.0             2438.0
# 9   2022-04-05            3405.0             551.0             2414.0
# 10  2022-04-06            3385.0             538.0             2374.0
# 11  2022-04-07            3330.0             540.0             2401.0
# ...

# %%
indexv = df_stock.iloc[3:,0]
indexv
# Out:
# 3     2022-03-28
# 4     2022-03-29
# 5     2022-03-30
# 6     2022-03-31
# 7     2022-04-01
# 8     2022-04-04
# 9     2022-04-05
# 10    2022-04-06
# 11    2022-04-07
# 12    2022-04-08
# 13    2022-04-11
# 14    2022-04-12
# 15    2022-04-13
# 16    2022-04-14
# 17    2022-04-15
# 18    2022-04-18
# 19    2022-04-19
# 20    2022-04-20
# 21    2022-04-21
# 22    2022-04-22
# 23    2022-04-25
# 24    2022-04-26
# Name: 0, dtype: object

# %%
columnsa = df_stock.iloc[0,1:]
columnsa
# Out:
# 1        Adj Close
# 2        Adj Close
# 3        Adj Close
# 4        Adj Close
# 5        Adj Close
#            ...
# 15950       Volume
# 15951       Volume
# 15952       Volume
# 15953       Volume
# 15954       Volume
# Name: 0, Length: 15954, dtype: object

# %%
columnsb = df_stock.iloc[1,1:]
columnsb
# Out:
# 1        1301.T
# 2        1332.T
# 3        1333.T
# 4        1352.T
# 5        1375.T
#           ...
# 15950    6541.T
# 15951    7758.T
# 15952    7862.T
# 15953    8287.T
# 15954    9358.T
# Name: 1, Length: 15954, dtype: object

# %%
values = df_stock.iloc[3:,1:]
values
# Out:
#                1                 2                  3                  4      \
# 3   3419.22412109375  577.939208984375  2515.811279296875  1199.016357421875
# 4             3390.0             571.0             2504.0             1200.0
# 5             3355.0             558.0             2444.0             1219.0
# 6             3330.0             548.0             2397.0             1219.0
# 7             3435.0             549.0             2411.0             1220.0
# 8             3420.0             555.0             2438.0             1220.0
# 9             3405.0             551.0             2414.0             1219.0
# 10            3385.0             538.0             2374.0             1219.0
# 11            3330.0             540.0             2401.0             1219.0
# 12            3275.0             552.0             2411.0             1219.0
# 13            3250.0             557.0             2397.0             1218.0
# ...

# %%
df_stock2 = pd.DataFrame(values,index=indexv, columns=[columnsa, columnsb])

# %%
df_stock2
# Out:
# 0          Adj Close                                                          \
# 1             1301.T 1332.T 1333.T 1352.T 1375.T 1376.T 1377.T 1379.T 1384.T
# 0
# 2022-03-28       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-03-29       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-03-30       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-03-31       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-01       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-04       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-05       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-06       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-07       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-08       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
df_stock2u = df_stock2.unstack()

# %%
df_stock2.index
# Out:
# Index(['2022-03-28', '2022-03-29', '2022-03-30', '2022-03-31', '2022-04-01',
#        '2022-04-04', '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08',
#        '2022-04-11', '2022-04-12', '2022-04-13', '2022-04-14', '2022-04-15',
#        '2022-04-18', '2022-04-19', '2022-04-20', '2022-04-21', '2022-04-22',
#        '2022-04-25', '2022-04-26'],
#       dtype='object', name=0)

# %%
df_stock2.columns
# Out:
# MultiIndex([('Adj Close',  '1301.T'),
#             ('Adj Close',  '1332.T'),
#             ('Adj Close',  '1333.T'),
#             ('Adj Close',  '1352.T'),
#             ('Adj Close',  '1375.T'),
#             ('Adj Close',  '1376.T'),
#             ('Adj Close',  '1377.T'),
#             ('Adj Close',  '1379.T'),
#             ('Adj Close',  '1384.T'),
#             ('Adj Close',  '1413.T'),
#             ...
#             (   'Volume',  '1737.T'),
#             (   'Volume',  '2281.T'),
#             (   'Volume', '25935.T'),
#             (   'Volume',  '3658.T'),
#             (   'Volume',  '6271.T'),
#             (   'Volume',  '6541.T'),
#             (   'Volume',  '7758.T'),
#             (   'Volume',  '7862.T'),
#             (   'Volume',  '8287.T'),
#             (   'Volume',  '9358.T')],
#            names=[0, 1], length=15954)

# %%
df_stock2.pivot(index=[index, 'Symbols'], columns='Attributes')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_158684/4157207263.py in <module>
# ----> 1 df_stock2.pivot(index=[index, 'Symbols'], columns='Attributes')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     494         # error: Unsupported operand types for + ("List[Any]" and "ExtensionArray")
#     495         # error: Unsupported left operand type for + ("ExtensionArray")
# --> 496         indexed = data.set_index(
#     497             cols + columns_listlike, append=append  # type: ignore[operator]
# ...
