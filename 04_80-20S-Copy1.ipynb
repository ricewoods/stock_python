# %%
import numpy as np
import pandas as pd
import datetime as dt
from pandas_datareader import DataReader
from pandas import Series, DataFrame

# %%
filedate = '20220407'

# %%
df_stock = pd.read_csv('data/stock_' + filedate + '.csv', index_col=0, header=[0,1], parse_dates=[0])

# %%
# 階層構造を逆にすることができます。今回は列方向で試します。
df_stock2 = df_stock.swaplevel('Attributes','Symbols',axis=1)

# %%
df_stock2.sort_values(by=['Symbols', 'Attributes'], axis=1, inplace=True)

# %%
# マルチインデックスのカラム名を取得する
list = df_stock2.columns.get_level_values('Symbols')

# %%
# RSIの計算
def rsi(df):
    # 前日との差分を計算
    df_diff = df[i,"Close"].diff(1)

    # 計算用のDataFrameを定義
    df_up, df_down = df_diff.copy(), df_diff.copy()
    
    # df_upはマイナス値を0に変換
    # df_downはプラス値を0に変換して正負反転
    df_up[df_up < 0] = 0
    df_down[df_down > 0] = 0
    df_down = df_down * -1
    
    # 期間03でそれぞれの平均を算出
    df_up_sma03 = df_up.rolling(window=3, center=False).mean()
    df_down_sma03 = df_down.rolling(window=3, center=False).mean()

    # RSIを算出
    df[i, "RSI"] = 100.0 * (df_up_sma03 / (df_up_sma03 + df_down_sma03))

    return df

for i in list: 
    df_stock2 = rsi(df_stock2)
# Out:
# C:\Users\ricew\AppData\Local\Temp/ipykernel_240656/2502226233.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i, "RSI"] = 100.0 * (df_up_sma03 / (df_up_sma03 + df_down_sma03))

# %%
df_stock2
# Out:
# Symbols          1301.T                                                1332.T  \
# Attributes    Adj Close   Close    High     Low    Open    Volume   Adj Close
# Date
# 2022-03-08  3150.862061  3225.0  3270.0  3220.0  3250.0   39600.0  502.598938
# 2022-03-09  3141.092041  3215.0  3250.0  3215.0  3225.0   20200.0  494.668396
# 2022-03-10  3189.942627  3265.0  3270.0  3235.0  3260.0   20700.0  530.355896
# 2022-03-11  3170.402344  3245.0  3265.0  3220.0  3220.0   21300.0  533.329834
# 2022-03-14  3165.517334  3240.0  3270.0  3200.0  3200.0   23400.0  555.138855
# 2022-03-15  3189.942627  3265.0  3290.0  3230.0  3230.0   21500.0  561.086792
# 2022-03-16  3233.907959  3310.0  3315.0  3280.0  3285.0   36000.0  558.112854
# 2022-03-17  3272.988525  3350.0  3350.0  3300.0  3350.0   37100.0  565.052063
# 2022-03-18  3316.954102  3395.0  3395.0  3355.0  3395.0   68700.0  560.095459
# 2022-03-22  3321.839111  3400.0  3460.0  3400.0  3415.0   63900.0  565.052063
# 2022-03-23  3400.000000  3480.0  3480.0  3420.0  3440.0   44500.0  575.956604
# 2022-03-24  3390.229980  3470.0  3475.0  3450.0  3475.0   39200.0  565.052063
# 2022-03-25  3453.735596  3535.0  3565.0  3470.0  3500.0  101400.0  572.982605
# 2022-03-28  3429.310303  3510.0  3575.0  3505.0  3560.0  107700.0  577.939209
# 2022-03-29  3400.000000  3480.0  3560.0  3460.0  3560.0  132900.0  571.000000
# 2022-03-30  3355.000000  3355.0  3410.0  3320.0  3400.0   77700.0  558.000000
# 2022-03-31  3330.000000  3330.0  3400.0  3330.0  3340.0   25800.0  548.000000
# 2022-04-01  3435.000000  3435.0  3440.0  3300.0  3320.0   36900.0  549.000000
# 2022-04-04  3420.000000  3420.0  3435.0  3390.0  3435.0   27600.0  555.000000
# 2022-04-05  3405.000000  3405.0  3425.0  3380.0  3420.0   16000.0  551.000000
# 2022-04-01    0.000000    0.000000   28.260870  27.777778    0.000000
# 2022-04-04   44.094488   27.272727   27.083333   3.571429   14.634146
# 2022-04-05   93.103448   68.421053   56.521739  36.363636   43.750000
# 2022-04-06   60.447761   65.000000    0.000000  14.000000   46.666667
# 2022-04-07   26.881720   61.111111    0.000000  18.918919   17.777778
#
# Symbols         9995.T      9997.T
# Attributes         RSI         RSI
# Date
# 2022-03-08         NaN         NaN
# 2022-03-09         NaN         NaN
# 2022-03-10         NaN         NaN
# 2022-03-11   60.869565   75.000000
# 2022-03-14   60.869565   86.363636
# 2022-03-15   43.750000   72.727273
# 2022-03-16   80.000000   59.259259
# 2022-03-17  100.000000   71.052632
# 2022-03-18  100.000000   62.068966
# 2022-03-22  100.000000  100.000000
# 2022-03-23   33.333333  100.000000
# 2022-03-24   66.666667   69.696970
# 2022-03-25   33.333333   66.666667
# 2022-03-28   37.500000   23.809524
# 2022-03-29    0.000000   79.310345
# 2022-03-30    0.000000   47.368421
# 2022-03-31   15.789474   66.666667
# 2022-04-01   12.500000   65.853659
# 2022-04-04   45.454545   90.000000
# 2022-04-05   18.181818   90.909091
# 2022-04-06   13.333333   65.000000
# 2022-04-07    0.000000   41.935484
#
# [22 rows x 18613 columns]

# %%
# High-Lowの計算結果を新たな列として追加
for i in list: 
    df_stock2[i, 'diff'] = df_stock2[i, 'High'] - df_stock2[i, 'Low']
    df_stock2[i, 'eighty'] = df_stock2[i, 'High'] - df_stock2[i, 'diff'] * 0.2
    df_stock2[i, 'twenty'] = df_stock2[i, 'Low'] + df_stock2[i, 'diff'] * 0.2
    df_stock2[i, 'RSI_diff'] = df_stock2[i,"RSI"].diff(1)
# Out:
# C:\Users\ricew\AppData\Local\Temp/ipykernel_72920/2650847954.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stock2[i, 'diff'] = df_stock2[i, 'High'] - df_stock2[i, 'Low']
# C:\Users\ricew\AppData\Local\Temp/ipykernel_72920/2650847954.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stock2[i, 'eighty'] = df_stock2[i, 'High'] - df_stock2[i, 'diff'] * 0.2
# C:\Users\ricew\AppData\Local\Temp/ipykernel_72920/2650847954.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stock2[i, 'twenty'] = df_stock2[i, 'Low'] + df_stock2[i, 'diff'] * 0.2
# C:\Users\ricew\AppData\Local\Temp/ipykernel_72920/2650847954.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_stock2[i, 'RSI_diff'] = df_stock2[i,"RSI"].diff(1)

# %%
df_stock2.sort_values(by=['Symbols', 'Attributes'], axis=1, inplace=True)

# %%
# 日付の比較Datetimeから最後の日のみを取得
df_stock3 = df_stock2.tail(1)

# %%
df_stock3 = df_stock3.T

# %%
df_stock3 = df_stock3.pivot_table(index=['Symbols'], columns=['Attributes'])

# %%
df_stock3 = df_stock3.droplevel(0, axis=1)

# %%
# 日付の比較Datetimeから日付のみを取得して比較
df_stock4 = df_stock3[(df_stock3['RSI'] < 30) &
                 (df_stock3['Open'] >= df_stock3['eighty']) &
                 (df_stock3['Close'] <= df_stock3['twenty'])
                 ]

# %%
# 日付の比較Datetimeから日付のみを取得して比較
df_stock5 = df_stock3[(df_stock3['RSI'] > 70) &
                 (df_stock3['Close'] >= df_stock3['eighty']) &
                 (df_stock3['Open'] <= df_stock3['twenty'])
                 ]

# %%
df_stock4.to_csv('data/pin_80_20_買い_' + filedate + '.csv')

# %%
df_stock5.to_csv('data/pin_80_20_売り_' + filedate + '.csv')
